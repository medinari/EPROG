# %% [markdown]
# # Einführung in das Programmieren - Übung 8
# # Objektorientiertes Programmieren (Teil 1)
#
# ### Sie dürfen für diese Übung auch Konzepte/Funktionen verwenden, die wir nicht bereits behandelt haben

# %% [markdown]
# ### Aufgabe 1
#
# Erstellen Sie eine Klasse `Radian`, die Winkel in Grad (degree) zu Bogenmaß (radian) umwandelt. Die Klasse hat das folgende Instanzattribut:
#
# - `degree: float`
#   Repräsentiert den Winkel in Grad.
#
# Die Klasse hat die folgenden Instanzmethoden:
#
# - `__init__(self, degree: float)`
#   Initialisiert dieses Instanzattribut.
#
# - `rad(self) -> float`
#   Gibt den Winkel im Bogenmaß für diesen Winkel in Grad zurück. Die Umrechnung von Grad in Bogenmaß ist definiert als `(a * (pi/180.0))`, wobei `a` der Winkel in Grad ist und `pi` gleich 3,14 ist.
#
# - `print(self)`
#   Gibt beide Winkel aus. Die Ausgaben sollen auf 2 Dezimalstellen formatiert sein.
#   Format: „Der Winkel in Grad ist `<deg>` und der Winkel im Bogenmaß ist `<rad>`“, wobei `<deg>` der Winkel in Grad und `<rad>` der Winkel im Bogenmaß ist.
#
# #### Beispielprogramm-Ausführung:
# ```python
# c = Radian(90)
# print(c.rad())
# c.print()
# ```
# #### Beispielausgabe:
# ```plaintext
# 1.57
# Der Winkel in Grad ist 90.00 und der Winkel im Bogenmaß ist 1.57

# %%
# your code here

# %% [markdown]
# #### `Klassenhierarchie für Aufgaben 2, 3, 4 und 5`
#
# ##### Am Ende der Datei finden Sie Beispiel-outputs für Aufgaben 2-5!
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Aufgabe 2
#
# Beachten Sie die gegebene Klassenhierarchie, die Distanzen zwischen 2 Vektoren modelliert. Sie sollen die Klassen in dieser und den folgenden Aufgaben implementieren.
#
# In dieser Aufgabe sollen Sie die Klasse `Distance` implementieren, die die Basisklasse für eindimensionale (1D) Vektoren darstellt. Die Klasse besitzt die folgenden Instanzattribute:
#
# - `x: int`
#   Die Anzahl der Vektoren.
#
# Die Klasse besitzt die folgenden Instanzmethoden:
#
# - `__init__(self, x: int)`
#   Initialisiert das Instanzattribut.
#
# - `to_string(self) -> str`
#   Gibt eine String-Repräsentation der Form `"<Art der Distanz>: Anzahl der Vektoren = <x_value>"` zurück, wobei `<Art der Distanz>` der Name der Klasse ist, und `<x_value>` den Wert des entsprechenden Attributs darstellt.
#
# - `dist(self) -> float`
#   Gibt die Distanz zwischen 2 Vektoren als `float` zurück. Diese Methode muss von allen konkreten Unterklassen implementiert werden. In der `Distance`-Klasse wird ein `NotImplementedError` ausgelöst.
#
# **Hinweise**
# - In der `to_string` Methode brauchen Sie den Namen der Klasse. Überlegen/recherchieren Sie, wie Sie innerhalb der Klasse auf diesen zugreifen können.

# %%
# your code here

# %% [markdown]
# ### Aufgabe 3 – Implementierung der konkreten Unterklasse Minkowski
#
# In dieser Aufgabe sollen Sie die konkrete Unterklasse `Minkowski` implementieren, die eine Minkowski-Distanz darstellt und die Basisklasse `Distance` erweitert. Die Klasse besitzt die folgenden zusätzlichen Instanzattribute:
#
# - `vect1: list`
#   Der erste Vektor.
#
# - `vect2: list`
#   Der zweite Vektor.
#
# Die Klasse besitzt die folgenden Instanzmethoden (verwenden Sie den Code der Basisklasse, um unnötige Code-Duplikation zu vermeiden):
#
# - `__init__(self, x: int, vect1: list, vect2: list)`
#   Setzt die beiden Instanzattribute (zusätzlich zu den Attributen der Basisklasse `Distance`).
#
# - `to_string(self) -> str`
#   Gibt eine String-Repräsentation der Form `"Minkowski: Anzahl der Vektoren = <x_value>, vektor_1 = <vect1_value>, vektor_2 = <vect2_value>"` zurück, wobei `<_value>` den Wert des entsprechenden Attributs darstellt.
#
# - `dist(self) -> float`
#   Gibt die Minkowski-Distanz zwischen den beiden Vektoren als `float` zurück. Das Ergebnis soll auf 4 Dezimalstellen gerundet sein. Die Minkowski-Distanz ist definiert als
# $$
# \left( \sum_{i=1}^n \left( |x(i) - y(i)|^p \right) \right)^{\frac{1}{p}}
# $$
# wobei \( p=2 \). Die Vektoren `x` und `y` sind dabei jeweils der erste und der zweite Vektor.
#
# #### Hinweise:
# - Verwenden Sie `super().some_method()`, um auf die Implementierung von `some_method` der Oberklasse zuzugreifen.

# %%
# your code here

# %% [markdown]
# ### Aufgabe 4 – Implementierung der konkreten Unterklasse Manhattan
#
# In dieser Aufgabe sollen Sie die konkrete Unterklasse `Manhattan` implementieren, die eine City-Block-Distanz darstellt und die Basisklasse `Distance` erweitert. Die Klasse besitzt die folgenden zusätzlichen Instanzattribute:
#
# - `vect1: list`
#   Der erste Vektor.
#
# - `vect2: list`
#   Der zweite Vektor.
#
# Die Klasse besitzt die folgenden Instanzmethoden (verwenden Sie den Code der Basisklasse, um unnötige Code-Duplikation zu vermeiden):
#
# - `__init__(self, x: int, vect1: list, vect2: list)`
#   Setzt die beiden Instanzattribute (zusätzlich zu den Attributen der Basisklasse `Distance`).
#
# - `to_string(self) -> str`
#   Gibt eine String-Repräsentation der Form `"Manhattan: Anzahl der Vektoren = <x_value>, vektor_1 = <vect1_value>, vektor_2 = <vect2_value>"` zurück, wobei `<_value>` den Wert des entsprechenden Attributs darstellt.
#
# - `dist(self) -> float`
#   Gibt die Manhattan-Distanz zwischen den beiden Vektoren als `float` zurück. Das Ergebnis sollte auf 4 Dezimalstellen gerundet sein. Die Manhattan-Distanz ist definiert als
#   $$
#   \sum_{i=1}^n |x(i) - y(i)|
#   $$
#   wobei `x` und `y` der erste und zweite Vektor sind.
#
# #### Hinweise:
# - Verwenden Sie `super().some_method()`, um auf die Implementierung von `some_method` der Oberklasse zuzugreifen.

# %%
# your code here

# %% [markdown]
# ### Aufgabe 5 (Freiwillige Zusatzaufgabe) – Implementierung der konkreten Unterklasse Euclidean
#
# In dieser Aufgabe sollen Sie die konkrete Unterklasse `Euclidean` implementieren, die eine euklidische Distanz darstellt und die Basisklasse `Minkowski` erweitert. Die Klasse besitzt keine zusätzlichen Instanzattribute.
#
# Die Klasse hat die folgenden Instanzmethoden (verwenden Sie den Code der Basisklassen, um unnötige Code-Duplikation zu vermeiden):
#
# - `__init__(self, x: int, vect1: list, vect2: list)`
#   Initialisiert beide Instanzattribute (zusätzlich zu den Attributen der Basisklasse `Distance`). Die Vektor-Parameter dienen nur der Benutzerfreundlichkeit. Intern werden die Attribute `vect1` und `vect2` an die Elternklasse `Minkowski` übergeben.
#
# - `to_string(self) -> str`
#   Gibt eine Zeichenketten-Repräsentation der Form `"Euclidean: Anzahl der Vektoren = <x_value>, vektor_1 = <vect1_value>, vektor_2 = <vect2_value>"` zurück, wobei `<_value>` den Wert des entsprechenden Attributs darstellt.
#
# - `dist(self) -> float`
#   Gibt die euklidische Distanz zwischen den beiden Vektoren als `float` zurück. Das Ergebnis sollte auf 4 Dezimalstellen gerundet sein. Die euklidische Distanz ist definiert als
#   $$
#   \sqrt{\sum_{i=1}^n (x(i) - y(i))^2}
#   $$
#   wobei `x` und `y` der erste und zweite Vektor sind.
#
# #### Hinweise:
# - Die Anforderung, „Code aus Superklassen wiederzuverwenden, um unnötige Code-Duplikation zu vermeiden“, ist in dieser Aufgabe besonders wichtig. Je nach Implementierung ist es möglicherweise nicht notwendig, Methoden der Superklasse `Minkowski` zu überschreiben.

# %%
# your code here

# %% [markdown]
# ### Kombinierte Beispiele für die Aufgaben 2-5
#
# #### Beispielprogramm-Ausführung:
# ```python
# vect1 = [1, 2, 3]
# vect2 = [4, 5, 6]
#
# d = Distance(2)
# print(d.to_string())
# try:
#     d.dist()
# except NotImplementedError:
#     print("NotImplementedError")
#
# k = Minkowski(2, vect1, vect2)
# print(k.to_string())
# print("Minkowski-Distanz:", k.dist())
#
# m = Manhattan(2, vect1, vect2)
# print(m.to_string())
# print("Manhattan-Distanz:", m.dist())
#
# e = Euclidean(2, vect1, vect2)
# print(e.to_string())
# print("Euklidische Distanz:", e.dist())

# %% [markdown]
# #### Beispielausgabe:
# ```plaintext
# Distance: Anzahl der Vektoren = 2
# NotImplementedError
# Minkowski: Anzahl der Vektoren = 2, vektor_1 = [1, 2, 3], vektor_2 = [4, 5, 6]
# Minkowski-Distanz: 5.1962
# Manhattan: Anzahl der Vektoren = 2, vektor_1 = [1, 2, 3], vektor_2 = [4, 5, 6]
# Manhattan-Distanz: 9.0000
# Euclidean: Anzahl der Vektoren = 2, vektor_1 = [1, 2, 3], vektor_2 = [4, 5, 6]
# Euklidische Distanz: 5.1962
